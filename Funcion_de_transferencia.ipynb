# %% [markdown]
# <a href="https://colab.research.google.com/github/JRiveraB23/SyS05/blob/main/Funcion_de_transferencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2023-11-19 at 1.34.50 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-19 at 1.34.50 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-11-19 at 1.34.50 PM (3).jpeg](data:image/jpeg;base64,...)
